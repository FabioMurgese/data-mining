# %% [markdown]
# # Generalized Sequential Pattern

# %%
import gsp as gsp
import pandas as pd
import subprocess
import datetime
import os
import tqdm

img = 'plots/figure_{}.png'
dataFolder = '../../data/{}'

# %%
def load_dataset():
    df = pd.read_csv(dataFolder.format('customer_supermarket.csv'), sep='\t', index_col=0).drop_duplicates()

    df['Sale'] = df['Sale'].str.replace(",", ".").astype(float)  # replace ',' with '.' to make Sale type as float64
    df['CustomerID'] = df['CustomerID'].astype('Int64')
    df['BasketDate'] = pd.to_datetime(df['BasketDate'])
    df = df[df['CustomerID'].notna()]
    return df


def load_customer_baskets():
    df = load_dataset()

    df['ProdID'] = df['ProdID'].astype('category')

    # Create a dictionary of ProdID (key) and its mapping to an integer as value
    prod_n_mapping = dict(zip(df['ProdID'], df['ProdID'].cat.codes))

    # Create a dictionary of mapped ProdID to int (key) and its description as value
    prod_cat_descr = dict(zip(df['ProdID'].cat.codes, df['ProdDescr']))

    df = df[['CustomerID', 'ProdID', 'BasketID', 'BasketDate']]
    df = df.sort_values(by='BasketDate')
    df = df.groupby(['CustomerID', 'BasketID'])['ProdID'].apply(list).reset_index()
    df = df.groupby('CustomerID')['ProdID'].apply(list).reset_index()
    customer_baskets = []
    for index, row in df.iterrows():
        customer_baskets.append({
            'customer_id': row['CustomerID'],
            'baskets': row['ProdID']
        })
    return customer_baskets, prod_n_mapping, prod_cat_descr

# %% [markdown]
# """
# The input file format is defined as follows. It is a text file where each line represents a sequence
# from a sequence database. Each item from a sequence is a positive integer and items from the same
# itemset within a sequence are separated by single space. Note that it is assumed that items within a
# same itemset are sorted according to a total order and that no item can appear twice in the same itemset.
#
# The value "-1" indicates the end of an itemset.
# The value "-2" indicates the end of a sequence (it appears at the end of each line).
#
# For example, the input file "contextPrefixSpan.txt" contains the following four lines (four sequences).
#
#     1 -1 1 2 3 -1 1 3 -1 4 -1 3 6 -1 -2
#     1 4 -1 3 -1 2 3 -1 1 5 -1 -2
#     5 6 -1 1 2 -1 4 6 -1 3 -1 2 -1 -2
#     5 -1 7 -1 1 6 -1 3 -1 2 -1 3 -1 -2
#
# The first line represents a sequence where the itemset {1} is followed by the itemset {1, 2, 3}, followed by the itemset {1, 3}, followed by the itemset {4}, followed by the itemset {3, 6}. The next lines follow the same format.
#
#
# @CONVERTED_FROM_TEXT
# @ITEM=1=apple
# @ITEM=2=orange
# @ITEM=3=tomato
# @ITEM=4=milk
# @ITEM=5=bread
# @ITEM=6=noodle
# @ITEM=7=rice
# @ITEM=-1=|
#
# """

# %%
if not os.path.isfile('input.txt'):

    gsp_dataset, prod_n_mapping, prod_cat_descr = load_customer_baskets()
    dataset = [c['baskets'] for c in gsp_dataset]

    # This is to save the mapping between the ProdIDs and their Descriptions
    # in order to have a textual description in the end
    with open('input.txt', 'w') as f:
        f.write('@CONVERTED_FROM_TEXT\n')
        f.write('@ITEM=-1=|\n')

        for k, v in prod_cat_descr.items():
            f.write('@ITEM={}={}\n'.format(k, v))

    # Create the input.txt file that will be passed to the library
    with open('input.txt', 'a') as f:

        for sequence in tqdm.tqdm(dataset):
            string = ""

            if len(sequence)>1:
                for itemset in sequence:
                    for item in sorted(itemset, key=str.lower):
                       string += "{} ".format(prod_n_mapping[item])
                    string += "-1 " #  The value "-1" indicates the end of an itemset.
                string += "-2" # The value "-2" indicates the end of a sequence (it appears at the end of each line).
                f.write(string+"\n")

# %%
support_percentage = "5%"

# This run the process
if not os.path.isfile("results/results_support_{}.txt".format(support_percentage)):

    start = datetime.datetime.now()
    subprocess.call(["java", "-jar", "spmf.jar", "run", "GSP", "input.txt", "results/results_support_{}.txt".format(support_percentage),
                     "{}".format(support_percentage), "false"])
    end = datetime.datetime.now()
    print("Total seconds elapsed {}s".format((end-start).total_seconds()))

# %%
# read output rules
lines = []
try:
    with open("results/results_support_{}.txt".format(support_percentage), "rU") as f:
        lines = f.readlines()
except:
    print
    "read_output error"

patterns = []
for line in lines:
    line = line.strip()
    patterns.append(line.split(" -1 "))

n_pattern_found = 0
sequences = []
supp = []

useful = 0
for p in patterns:
    p = p[0].split("|")

    if len(p) > 2:
        useful += 1

        sx_str = ""
        n_elements = len(p)
        for i, el in enumerate(p):
            if i == (n_elements-1):
                el = el.replace("#SUP: ", "")
                supp.append(int(el))

            else:
                if sx_str != "":
                    sx_str += ","+el.strip()
                else:
                    sx_str += el.strip()

        sequences.append(sx_str.strip())
        n_pattern_found += 1

df = pd.DataFrame({'Sequences': sequences, 'Support': supp})
df = df.sort_values(by=['Support'], ascending=False)
print(df[:150].set_index('Sequences').to_markdown())

df.to_csv('results/results_support_{}.csv'.format(support_percentage))
# Out:
# | Sequences                                                                                                |   Support |
# |:---------------------------------------------------------------------------------------------------------|----------:|
# | CREAM HANGING HEART T-LIGHT HOLDER,CREAM HANGING HEART T-LIGHT HOLDER                                    |       416 |
# | REGENCY CAKESTAND 3 TIER,REGENCY CAKESTAND 3 TIER                                                        |       363 |
# | JUMBO BAG RED RETROSPOT,JUMBO BAG RED RETROSPOT                                                          |       317 |
# | ASSORTED COLOUR BIRD ORNAMENT,ASSORTED COLOUR BIRD ORNAMENT                                              |       294 |
# | LUNCH BAG RED RETROSPOT,LUNCH BAG RED RETROSPOT                                                          |       284 |
# | PARTY BUNTING,PARTY BUNTING                                                                              |       282 |
# | SET OF 3 CAKE TINS PANTRY DESIGN,SET OF 3 CAKE TINS PANTRY DESIGN                                        |       249 |
# | JUMBO BAG RED RETROSPOT,JUMBO BAG VINTAGE DOILY                                                          |       237 |
# | JUMBO BAG VINTAGE DOILY,JUMBO BAG VINTAGE DOILY                                                          |       236 |
# | LUNCH BAG  BLACK SKULL.,LUNCH BAG  BLACK SKULL.                                                          |       233 |
# | LUNCH BAG SUKI DESIGN,LUNCH BAG SUKI DESIGN                                                              |       230 |
# | CREAM HANGING HEART T-LIGHT HOLDER,CREAM HANGING HEART T-LIGHT HOLDER,CREAM HANGING HEART T-LIGHT HOLDER |       230 |
# | LUNCH BAG RED RETROSPOT,LUNCH BAG  BLACK SKULL.                                                          |       215 |
# | REGENCY CAKESTAND 3 TIER,SET OF 3 REGENCY CAKE TINS                                                      |       213 |
# | LUNCH BAG RED RETROSPOT,LUNCH BAG VINTAGE DOILY                                                          |       213 |
# | LUNCH BAG CARS BLUE,LUNCH BAG RED RETROSPOT                                                              |       212 |
# | SPOTTY BUNTING,SPOTTY BUNTING                                                                            |       212 |
# | LUNCH BAG  BLACK SKULL.,LUNCH BAG RED RETROSPOT                                                          |       211 |
# | LUNCH BAG CARS BLUE,LUNCH BAG CARS BLUE                                                                  |       210 |
# | LUNCH BAG RED RETROSPOT,LUNCH BAG SPACEBOY DESIGN                                                        |       209 |
# | LUNCH BAG VINTAGE DOILY,LUNCH BAG VINTAGE DOILY                                                          |       209 |
# | LUNCH BAG RED RETROSPOT,LUNCH BAG SUKI DESIGN                                                            |       208 |
# | JUMBO BAG VINTAGE DOILY,JUMBO BAG RED RETROSPOT                                                          |       206 |
# | LUNCH BAG PINK POLKADOT,LUNCH BAG RED RETROSPOT                                                          |       204 |
# | JUMBO BAG RED RETROSPOT,LUNCH BAG RED RETROSPOT                                                          |       204 |
# | HEART OF WICKER SMALL,HEART OF WICKER SMALL                                                              |       203 |
# | LUNCH BAG PINK POLKADOT,LUNCH BAG PINK POLKADOT                                                          |       202 |
# | POPCORN HOLDER,POPCORN HOLDER                                                                            |       202 |
# | POSTAGE,POSTAGE                                                                                          |       201 |
# | LUNCH BAG SPACEBOY DESIGN,LUNCH BAG RED RETROSPOT                                                        |       201 |
# | LUNCH BAG RED RETROSPOT,JUMBO BAG RED RETROSPOT                                                          |       201 |
# | LUNCH BAG SPACEBOY DESIGN,LUNCH BAG SPACEBOY DESIGN                                                      |       201 |
# | PACK OF 72 RETROSPOT CAKE CASES,PACK OF 72 RETROSPOT CAKE CASES                                          |       199 |
# | LUNCH BAG RED RETROSPOT,LUNCH BAG PINK POLKADOT                                                          |       199 |
# | LUNCH BAG RED RETROSPOT,LUNCH BAG CARS BLUE                                                              |       198 |
# | PAPER CHAIN KIT 50'S CHRISTMAS,PAPER CHAIN KIT 50'S CHRISTMAS                                            |       198 |
# | PARTY BUNTING,SPOTTY BUNTING                                                                             |       197 |
# | LUNCH BAG SUKI DESIGN,LUNCH BAG RED RETROSPOT                                                            |       194 |
# | LUNCH BAG RED RETROSPOT,LUNCH BAG APPLE DESIGN                                                           |       194 |
# | LUNCH BAG WOODLAND,LUNCH BAG WOODLAND                                                                    |       193 |
# | LUNCH BAG CARS BLUE,LUNCH BAG  BLACK SKULL.                                                              |       191 |
# | LUNCH BAG SUKI DESIGN,LUNCH BAG  BLACK SKULL.                                                            |       190 |
# | JUMBO BAG RED RETROSPOT,JUMBO BAG PINK POLKADOT                                                          |       190 |
# | LUNCH BAG CARS BLUE,LUNCH BAG SUKI DESIGN                                                                |       190 |
# | JUMBO BAG RED RETROSPOT,JUMBO BAG APPLES                                                                 |       189 |
# | REGENCY CAKESTAND 3 TIER,REGENCY CAKESTAND 3 TIER,REGENCY CAKESTAND 3 TIER                               |       189 |
# | ALARM CLOCK BAKELIKE RED,ALARM CLOCK BAKELIKE RED                                                        |       189 |
# | LUNCH BAG APPLE DESIGN,LUNCH BAG APPLE DESIGN                                                            |       188 |
# | JUMBO BAG RED RETROSPOT,JUMBO BAG RED RETROSPOT,JUMBO BAG RED RETROSPOT                                  |       188 |
# | JUMBO BAG RED RETROSPOT,JUMBO BAG 50'S CHRISTMAS                                                         |       188 |
# | RABBIT NIGHT LIGHT,RABBIT NIGHT LIGHT                                                                    |       187 |
# | NATURAL SLATE HEART CHALKBOARD,NATURAL SLATE HEART CHALKBOARD                                            |       187 |
# | WOODEN PICTURE FRAME WHITE FINISH,WOODEN PICTURE FRAME WHITE FINISH                                      |       186 |
# | LUNCH BAG VINTAGE DOILY,JUMBO BAG VINTAGE DOILY                                                          |       186 |
# | LUNCH BAG  BLACK SKULL.,LUNCH BAG SUKI DESIGN                                                            |       186 |
# | JUMBO BAG PINK POLKADOT,JUMBO BAG RED RETROSPOT                                                          |       185 |
# | LUNCH BAG CARS BLUE,LUNCH BAG PINK POLKADOT                                                              |       184 |
# | LUNCH BAG SUKI DESIGN,LUNCH BAG SPACEBOY DESIGN                                                          |       184 |
# | SET OF 4 PANTRY JELLY MOULDS,SET OF 4 PANTRY JELLY MOULDS                                                |       183 |
# | LUNCH BAG SPACEBOY DESIGN,LUNCH BAG SUKI DESIGN                                                          |       183 |
# | JAM MAKING SET WITH JARS,JAM MAKING SET WITH JARS                                                        |       183 |
# | LUNCH BAG CARS BLUE,LUNCH BAG VINTAGE DOILY                                                              |       182 |
# | LUNCH BAG RED RETROSPOT,LUNCH BAG WOODLAND                                                               |       181 |
# | REX CASH+CARRY JUMBO SHOPPER,REX CASH+CARRY JUMBO SHOPPER                                                |       181 |
# | JUMBO BAG RED RETROSPOT,JUMBO BAG VINTAGE LEAF                                                           |       180 |
# | LUNCH BAG PINK POLKADOT,LUNCH BAG  BLACK SKULL.                                                          |       180 |
# | ROSES REGENCY TEACUP AND SAUCER,REGENCY CAKESTAND 3 TIER                                                 |       178 |
# | LUNCH BAG CARS BLUE,LUNCH BAG SPACEBOY DESIGN                                                            |       178 |
# | LUNCH BAG SUKI DESIGN,LUNCH BAG CARS BLUE                                                                |       178 |
# | LUNCH BAG WOODLAND,LUNCH BAG RED RETROSPOT                                                               |       177 |
# | LUNCH BAG  BLACK SKULL.,LUNCH BAG CARS BLUE                                                              |       176 |
# | WOODEN PICTURE FRAME WHITE FINISH,WOODEN FRAME ANTIQUE WHITE                                             |       175 |
# | LUNCH BAG SPACEBOY DESIGN,LUNCH BAG  BLACK SKULL.                                                        |       175 |
# | JUMBO BAG RED RETROSPOT,JUMBO BAG ALPHABET                                                               |       174 |
# | CREAM HANGING HEART T-LIGHT HOLDER,REGENCY CAKESTAND 3 TIER                                              |       174 |
# | LUNCH BAG PINK POLKADOT,LUNCH BAG SPACEBOY DESIGN                                                        |       174 |
# | LUNCH BAG PINK POLKADOT,LUNCH BAG CARS BLUE                                                              |       174 |
# | CREAM HANGING HEART T-LIGHT HOLDER,RED HANGING HEART T-LIGHT HOLDER                                      |       174 |
# | LUNCH BAG  BLACK SKULL.,LUNCH BAG PINK POLKADOT                                                          |       174 |
# | REGENCY CAKESTAND 3 TIER,ROSES REGENCY TEACUP AND SAUCER                                                 |       173 |
# | REGENCY CAKESTAND 3 TIER,CREAM HANGING HEART T-LIGHT HOLDER                                              |       173 |
# | REGENCY CAKESTAND 3 TIER,PARTY BUNTING                                                                   |       172 |
# | LUNCH BAG PINK POLKADOT,LUNCH BAG VINTAGE DOILY                                                          |       172 |
# | LUNCH BAG  BLACK SKULL.,LUNCH BAG SPACEBOY DESIGN                                                        |       172 |
# | RED HANGING HEART T-LIGHT HOLDER,CREAM HANGING HEART T-LIGHT HOLDER                                      |       172 |
# | CREAM HANGING HEART T-LIGHT HOLDER,HEART OF WICKER LARGE                                                 |       172 |
# | LUNCH BAG RED RETROSPOT,LUNCH BAG ALPHABET DESIGN                                                        |       172 |
# | LUNCH BAG PINK POLKADOT,LUNCH BAG SUKI DESIGN                                                            |       172 |
# | LUNCH BAG RED RETROSPOT,JUMBO BAG VINTAGE DOILY                                                          |       172 |
# | HEART OF WICKER SMALL,CREAM HANGING HEART T-LIGHT HOLDER                                                 |       171 |
# | PARTY BUNTING,REGENCY CAKESTAND 3 TIER                                                                   |       171 |
# | LUNCH BAG SPACEBOY DESIGN,LUNCH BAG VINTAGE DOILY                                                        |       171 |
# | LUNCH BAG CARS BLUE,JUMBO BAG RED RETROSPOT                                                              |       170 |
# | WOODEN FRAME ANTIQUE WHITE,WOODEN FRAME ANTIQUE WHITE                                                    |       170 |
# | LUNCH BAG  BLACK SKULL.,LUNCH BAG VINTAGE DOILY                                                          |       170 |
# | JUMBO BAG RED RETROSPOT,JUMBO BAG VINTAGE DOILY  JUMBO BAG RED RETROSPOT                                 |       170 |
# | LUNCH BAG VINTAGE DOILY,LUNCH BAG RED RETROSPOT                                                          |       170 |
# | ALARM CLOCK BAKELIKE RED,ALARM CLOCK BAKELIKE GREEN                                                      |       169 |
# | LUNCH BAG PINK POLKADOT,JUMBO BAG RED RETROSPOT                                                          |       169 |
# | LUNCH BAG SPACEBOY DESIGN,LUNCH BAG WOODLAND                                                             |       169 |
# | PARTY BUNTING,CREAM HANGING HEART T-LIGHT HOLDER                                                         |       169 |
# | LUNCH BAG SUKI DESIGN,LUNCH BAG PINK POLKADOT                                                            |       169 |
# | HEART OF WICKER LARGE,HEART OF WICKER LARGE                                                              |       169 |
# | CREAM HANGING HEART T-LIGHT HOLDER,ASSORTED COLOUR BIRD ORNAMENT                                         |       169 |
# | LUNCH BAG CARS BLUE,LUNCH BAG ALPHABET DESIGN                                                            |       169 |
# | JUMBO BAG VINTAGE DOILY,JUMBO BAG 50'S CHRISTMAS                                                         |       168 |
# | RECIPE BOX PANTRY YELLOW DESIGN,RECIPE BOX PANTRY YELLOW DESIGN                                          |       168 |
# | CREAM HANGING HEART T-LIGHT HOLDER,PARTY BUNTING                                                         |       167 |
# | LUNCH BAG RED RETROSPOT,LUNCH BAG RED RETROSPOT,LUNCH BAG RED RETROSPOT                                  |       167 |
# | JUMBO BAG RED RETROSPOT,LUNCH BAG VINTAGE DOILY                                                          |       167 |
# | LUNCH BAG APPLE DESIGN,LUNCH BAG VINTAGE DOILY                                                           |       167 |
# | JUMBO BAG PINK POLKADOT,JUMBO BAG PINK POLKADOT                                                          |       167 |
# | LUNCH BAG WOODLAND,LUNCH BAG  BLACK SKULL.                                                               |       166 |
# | LUNCH BAG WOODLAND,LUNCH BAG SPACEBOY DESIGN                                                             |       166 |
# | SET OF 3 CAKE TINS PANTRY DESIGN,REGENCY CAKESTAND 3 TIER                                                |       166 |
# | JUMBO BAG APPLES,JUMBO BAG RED RETROSPOT                                                                 |       165 |
# | LUNCH BAG SUKI DESIGN,LUNCH BAG APPLE DESIGN                                                             |       165 |
# | LUNCH BAG ALPHABET DESIGN,LUNCH BAG VINTAGE DOILY                                                        |       165 |
# | JUMBO BAG ALPHABET,JUMBO BAG RED RETROSPOT                                                               |       165 |
# | LUNCH BAG CARS BLUE,LUNCH BAG APPLE DESIGN                                                               |       165 |
# | LUNCH BAG SPACEBOY DESIGN,LUNCH BAG CARS BLUE                                                            |       164 |
# | CREAM HANGING HEART T-LIGHT HOLDER,HEART OF WICKER SMALL                                                 |       164 |
# | SET OF 3 CAKE TINS PANTRY DESIGN,SET OF 3 REGENCY CAKE TINS                                              |       164 |
# | JUMBO BAG RED RETROSPOT,LUNCH BAG PINK POLKADOT                                                          |       164 |
# | LUNCH BAG SUKI DESIGN,LUNCH BAG VINTAGE DOILY                                                            |       164 |
# | JUMBO BAG RED RETROSPOT,LUNCH BAG  BLACK SKULL.                                                          |       164 |
# | REGENCY CAKESTAND 3 TIER,GREEN REGENCY TEACUP AND SAUCER                                                 |       163 |
# | CREAM HANGING HEART T-LIGHT HOLDER,JUMBO BAG RED RETROSPOT                                               |       163 |
# | LUNCH BAG APPLE DESIGN,LUNCH BAG RED RETROSPOT                                                           |       162 |
# | LUNCH BAG SPACEBOY DESIGN,LUNCH BAG PINK POLKADOT                                                        |       162 |
# | ALARM CLOCK BAKELIKE GREEN,ALARM CLOCK BAKELIKE RED                                                      |       161 |
# | LUNCH BAG PINK POLKADOT,LUNCH BAG ALPHABET DESIGN                                                        |       161 |
# | JUMBO BAG ALPHABET,JUMBO BAG ALPHABET                                                                    |       161 |
# | LUNCH BAG  BLACK SKULL.,JUMBO BAG RED RETROSPOT                                                          |       161 |
# | LUNCH BAG RED RETROSPOT LUNCH BAG PINK POLKADOT,LUNCH BAG RED RETROSPOT                                  |       160 |
# | CREAM HANGING HEART T-LIGHT HOLDER,WOODEN PICTURE FRAME WHITE FINISH                                     |       160 |
# | HEART OF WICKER LARGE,CREAM HANGING HEART T-LIGHT HOLDER                                                 |       160 |
# | JUMBO BAG VINTAGE DOILY,LUNCH BAG VINTAGE DOILY                                                          |       160 |
# | LUNCH BAG PINK POLKADOT,LUNCH BAG APPLE DESIGN                                                           |       160 |
# | JUMBO BAG PINK POLKADOT,JUMBO BAG VINTAGE DOILY                                                          |       160 |
# | SET/5 RED RETROSPOT LID GLASS BOWLS,SET/5 RED RETROSPOT LID GLASS BOWLS                                  |       159 |
# | ASSORTED COLOUR BIRD ORNAMENT,ASSORTED COLOUR BIRD ORNAMENT,ASSORTED COLOUR BIRD ORNAMENT                |       159 |
# | LUNCH BAG  BLACK SKULL.,LUNCH BAG WOODLAND                                                               |       159 |
# | GREEN REGENCY TEACUP AND SAUCER,REGENCY CAKESTAND 3 TIER                                                 |       159 |
# | JUMBO BAG RED RETROSPOT,JUMBO BAG VINTAGE DOILY,JUMBO BAG RED RETROSPOT                                  |       158 |
# | LUNCH BAG RED RETROSPOT,LUNCH BAG RED RETROSPOT LUNCH BAG SUKI DESIGN                                    |       158 |
# | CREAM HANGING HEART T-LIGHT HOLDER,SMALL WHITE HEART OF WICKER                                           |       158 |
# | JUMBO SHOPPER VINTAGE RED PAISLEY,JUMBO BAG RED RETROSPOT                                                |       158 |
# | LUNCH BAG SUKI DESIGN,LUNCH BAG ALPHABET DESIGN                                                          |       158 |
# | ALARM CLOCK BAKELIKE GREEN,ALARM CLOCK BAKELIKE GREEN                                                    |       158 |
# <ipython-input-5-f643caf847f3>:4: DeprecationWarning: 'U' mode is deprecated
#   with open("results/results_support_{}.txt".format(support_percentage), "rU") as f:

# %%
row_with_more_sx = 0
for idx, row in df.iterrows():
    if "," in row['Sequences']:
        splitted = row['Sequences'].split(",")
        if len(set(splitted)) >= 2:
            row_with_more_sx += 1

print("Patterns found: {}".format(n_pattern_found))
# Out:
# Patterns found: 177
